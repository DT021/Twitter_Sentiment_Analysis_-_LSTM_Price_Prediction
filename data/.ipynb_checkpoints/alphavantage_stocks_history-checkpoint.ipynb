# %%
import pandas as pd
import config, requests, time

# %%
# https://www.alphavantage.co/documentation/

# %%
BASE_URL = 'https://www.alphavantage.co/query?function='
function = 'TIME_SERIES_DAILY' #returns daily data vs. intraday data
symbol = '' #stock ticker - single value allowed only
outputsize = 'full' #full or compact. compact returns 100 data points

# %%
request_URL = BASE_URL + \
f'{function}&symbol={symbol}&outputsize={outputsize}&apikey={config.ALPHA_VANTAGE_API}'

# %%
# create new (empty) dataframe
df = pd.DataFrame()

# %%
# list tickers to get data for
symbols = ['MSFT', 'AAPL', 'TSLA', 'JNJ', 'REGN', 'GILD']

# loop through ticker list, create dataframe for each, and join to dataframe created earlier
for symbol in symbols:
#     set request URL for GET request
    request_URL = BASE_URL + \
                f'{function}&symbol={symbol}&outputsize={outputsize}\
&apikey={config.ALPHA_VANTAGE_API}'
#     send GET request
    r = requests.get(request_URL)
#     create dataframe from GET response (transpose dataframe, as response flips
#     rows and columns (dates are in columns instead of rows)
    _ = pd.DataFrame(r.json()['Time Series (Daily)']).transpose()
#     rename columns to include ticker
    columns = [
        f'{symbol}_open',
        f'{symbol}_high',
        f'{symbol}_low',
        f'{symbol}_close',
        f'{symbol}_volume'
    ]
    _.columns = columns
#     join dataframe to "master" dataframe
    df = df.join(_, how='outer')
    time.sleep(15) #sleeping due to call limit on api (5 calls per minute)

# %%
df.head()
# Out:
#            MSFT_open MSFT_high MSFT_low MSFT_close MSFT_volume AAPL_open  \
# 2000-07-05   79.8700   79.8700  78.2500    78.5000    17412200   53.2500
# 2000-07-06   78.8700   81.6900  78.5000    80.9400    23936600   52.5000
# 2000-07-07   81.2700   82.8700  80.5600    82.0000    27076600   52.5900
# 2000-07-10   80.6900   81.3100  79.3700    79.4400    26344900   54.0900
# 2000-07-11   78.8100   80.5000  78.5000    79.1200    18582400   57.0000
#
#            AAPL_high AAPL_low AAPL_close AAPL_volume  ... REGN_open REGN_high  \
# 2000-07-05   55.1900  50.7500    51.6300     4736000  ...   29.0600   30.3100
# 2000-07-06   52.9400  49.6300    51.8100     5527600  ...   28.5600   29.4400
# 2000-07-07   54.8100  52.1300    54.4400     4707200  ...   29.1900   33.1900
# 2000-07-10   58.2500  53.7500    57.1300     7103500  ...   28.8100   30.0000
# 2000-07-11   59.2500  55.4400    56.9400     6391000  ...   29.7500   31.7500
#
#            REGN_low REGN_close REGN_volume GILD_open GILD_high GILD_low  \
# 2000-07-05  27.6300    30.0600      135200   71.0000   72.5900  70.2500
# 2000-07-06  26.5600    28.9400      157500   71.0600   73.5000  70.8800
# 2000-07-07  28.2500    29.6300      346500   74.0000   81.7500  74.0000
# 2000-07-10  28.6300    29.7500      275400   80.0000   81.4400  75.0000
# 2000-07-11  29.6300    31.3800      312800   80.0600   83.8800  79.1900
#
#            GILD_close GILD_volume
# 2000-07-05    70.9400      429100
# 2000-07-06    73.1300      493900
# 2000-07-07    80.3100     1233100
# 2000-07-10    79.3800      554400
# 2000-07-11    83.0000      553900
#
# [5 rows x 30 columns]

# %%
df.describe()
# Out:
#        MSFT_open MSFT_high MSFT_low MSFT_close MSFT_volume AAPL_open  \
# count       5032      5032     5032       5032        5032      5032
# unique      3123      3150     3150       3192        5023      4465
# top      27.0800   26.0000  25.5000    27.2500    42026600   19.0600
# freq          11        14       16         12           2         6
#
#        AAPL_high AAPL_low AAPL_close AAPL_volume  ... REGN_open REGN_high  \
# count       5032     5032       5032        5032  ...      5032      5032
# unique      4387     4439       4503        5013  ...      3848      3883
# top      15.0000  14.0000    15.0000     2460400  ...   24.5000   15.0000
# freq           8        9          6           2  ...         8        10
#
#        REGN_low REGN_close REGN_volume GILD_open GILD_high GILD_low  \
# count      5032       5032        5032      5032      5032     5032
# unique     3881       3922        4534      3428      3471     3523
# top     26.0000    13.0000      399600   46.0000   46.0000  45.0000
# freq          7          9           4         9         9        8
#
#        GILD_close GILD_volume
# count        5032        5032
# unique       3500        4976
# top       36.5000     3337300
# freq            8           3
#
# [4 rows x 30 columns]

# %%
df.isna().sum()
# Out:
# MSFT_open         0
# MSFT_high         0
# MSFT_low          0
# MSFT_close        0
# MSFT_volume       0
# AAPL_open         0
# AAPL_high         0
# AAPL_low          0
# AAPL_close        0
# AAPL_volume       0
# TSLA_open      2510
# TSLA_high      2510
# TSLA_low       2510
# TSLA_close     2510
# TSLA_volume    2510
# JNJ_open          0
# JNJ_high          0
# JNJ_low           0
# JNJ_close         0
# JNJ_volume        0
# REGN_open         0
# REGN_high         0
# REGN_low          0
# REGN_close        0
# REGN_volume       0
# GILD_open         0
# GILD_high         0
# GILD_low          0
# GILD_close        0
# GILD_volume       0
# dtype: int64

# %%
# Clean up dataframe

# remove N/A's
df.dropna(inplace=True)

# remove (potentially) unused columns
df = df[df.columns.drop(list(column for column in df.columns if column.lower()[-7:] == '_volume'))]

# sort index in ascending order
df.sort_index(ascending=True, inplace=True)

# %%
df.describe()
# Out:
#        MSFT_open MSFT_high MSFT_low MSFT_close AAPL_open AAPL_high AAPL_low  \
# count       2522      2522     2522       2522      2522      2522     2522
# unique      2108      2109     2118       2131      2415      2404     2414
# top      27.9300   28.2000  25.5000    25.8100  110.0000  160.0000  94.1000
# freq           5         5        5          6         4         3        3
#
#        AAPL_close TSLA_open TSLA_high  ...  JNJ_low JNJ_close REGN_open  \
# count        2522      2522      2522  ...     2522      2522      2522
# unique       2418      2243      2264  ...     2126      2137      2404
# top       97.3400   28.0000   30.0000  ...  64.8400  103.2200  367.0000
# freq            3         7         7  ...        5         5         5
#
#        REGN_high  REGN_low REGN_close GILD_open GILD_high GILD_low GILD_close
# count       2522      2522       2522      2522      2522     2522       2522
# unique      2415      2417       2430      2028      2119     2096       2062
# top     410.0000  178.0000   405.2500   70.0000   75.2500  70.7200    72.7800
# freq           5         4          3         7         6        5          6
#
# [4 rows x 24 columns]

# %%
df.to_csv('stocks_history.csv')
